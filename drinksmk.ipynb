# %% [markdown]
# <a href="https://colab.research.google.com/github/ufuomaibude/Machine-learning-Analysis-on-Drinking/blob/main/drinksmk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Red_smkdrk_range.xlsx")
df
# Out:
#          sex  age  height  weight  waistline  sight_left  sight_right  \
# 0       Male   35     170      75       90.0         1.0          1.0
# 1       Male   55     165      60       79.0         1.5          1.5
# 2     Female   60     155      50       78.0         1.0          0.9
# 3     Female   30     155      45       66.0         1.0          0.8
# 4       Male   45     160      70       79.0         0.5          0.5
# ...      ...  ...     ...     ...        ...         ...          ...
# 1996  Female   70     140      45       81.0         0.9          0.8
# 1997    Male   60     165      55       79.0         0.6          0.9
# 1998  Female   50     150      50       72.0         0.7          0.5
# 1999    Male   55     155      70       98.0         0.7          1.2
# 2000    Male   65     165      65       96.0         0.5          0.8
#
#       hear_left  hear_right  SBP  ...  LDL_chole  triglyceride  hemoglobin  \
# ...

# %%
#get metadata info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sex               2001 non-null   object
#  1   age               2001 non-null   int64
#  2   height            2001 non-null   int64
#  3   weight            2001 non-null   int64
#  4   waistline         2001 non-null   float64
#  5   sight_left        2001 non-null   float64
#  6   sight_right       2001 non-null   float64
#  7   hear_left         2001 non-null   int64
#  8   hear_right        2001 non-null   int64
#  9   SBP               2001 non-null   int64
#  10  DBP               2001 non-null   int64
#  11  BLDS              2001 non-null   int64
#  12  tot_chole         2001 non-null   int64
#  13  HDL_chole         2001 non-null   int64
#  14  LDL_chole         2001 non-null   int64
#  15  triglyceride      2001 non-null   int64
# ...

# %%
print(len(df),"\n")
print(df.shape,"\n")
print(df.index,"\n")
print(df.columns,"\n")
print(df.info(),"\n")
print(df.count(),"\n")
# Out:
# 2001
#
# (2001, 24)
#
# RangeIndex(start=0, stop=2001, step=1)
#
# Index(['sex', 'age', 'height', 'weight', 'waistline', 'sight_left',
#        'sight_right', 'hear_left', 'hear_right', 'SBP', 'DBP', 'BLDS',
#        'tot_chole', 'HDL_chole', 'LDL_chole', 'triglyceride', 'hemoglobin',
#        'urine_protein', 'serum_creatinine', 'SGOT_AST', 'SGOT_ALT',
#        'gamma_GTP', 'SMK_stat_type_cd', 'DRK_YN'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sex               2001 non-null   object
#  1   age               2001 non-null   int64
#  2   height            2001 non-null   int64
#  3   weight            2001 non-null   int64
#  4   waistline         2001 non-null   float64
#  5   sight_left        2001 non-null   float64
#  6   sight_right       2001 non-null   float64
# ...

# %%
df.head()
# Out:
#       sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0    Male   35     170      75       90.0         1.0          1.0          1
# 1    Male   55     165      60       79.0         1.5          1.5          1
# 2  Female   60     155      50       78.0         1.0          0.9          1
# 3  Female   30     155      45       66.0         1.0          0.8          1
# 4    Male   45     160      70       79.0         0.5          0.5          1
#
#    hear_right  SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0           1  120  ...        126            92        17.1              1
# 1           1  117  ...         81           138        15.9              1
# 2           1  128  ...        155           133        12.9              1
# 3           1  120  ...         77            80        13.7              1
# 4           1  136  ...        127           162        14.7              1
#
# ...

# %%
df.describe()
# Out:
#                age       height       weight    waistline   sight_left  \
# count  2001.000000  2001.000000  2001.000000  2001.000000  2001.000000
# mean     47.796102   162.143928    63.028486    80.745927     0.988806
# std      13.749197     9.210118    12.635216     9.735590     0.558448
# min      20.000000   135.000000    35.000000    51.000000     0.100000
# 25%      40.000000   155.000000    55.000000    74.000000     0.800000
# 50%      50.000000   160.000000    60.000000    81.000000     1.000000
# 75%      55.000000   170.000000    70.000000    87.000000     1.200000
# max      85.000000   190.000000   120.000000   115.000000     9.900000
#
#        sight_right    hear_left   hear_right          SBP          DBP  ...  \
# count  2001.000000  2001.000000  2001.000000  2001.000000  2001.000000  ...
# mean      1.037631     1.028486     1.027486   122.271864    75.912044  ...
# std       0.813786     0.166398     0.163536    14.334854     9.885052  ...
# ...

# %%
df.describe().transpose()
# Out:
#                    count        mean        std    min    25%    50%    75%  \
# age               2001.0   47.796102  13.749197   20.0   40.0   50.0   55.0
# height            2001.0  162.143928   9.210118  135.0  155.0  160.0  170.0
# weight            2001.0   63.028486  12.635216   35.0   55.0   60.0   70.0
# waistline         2001.0   80.745927   9.735590   51.0   74.0   81.0   87.0
# sight_left        2001.0    0.988806   0.558448    0.1    0.8    1.0    1.2
# sight_right       2001.0    1.037631   0.813786    0.1    0.8    1.0    1.2
# hear_left         2001.0    1.028486   0.166398    1.0    1.0    1.0    1.0
# hear_right        2001.0    1.027486   0.163536    1.0    1.0    1.0    1.0
# SBP               2001.0  122.271864  14.334854   87.0  112.0  120.0  131.0
# DBP               2001.0   75.912044   9.885052   44.0   70.0   76.0   82.0
# BLDS              2001.0  100.283358  24.633253   54.0   89.0   95.0  104.0
# ...

# %%
df.describe().BLDS
# Out:
# count    2001.000000
# mean      100.283358
# std        24.633253
# min        54.000000
# 25%        89.000000
# 50%        95.000000
# 75%       104.000000
# max       429.000000
# Name: BLDS, dtype: float64

# %%
df.describe().tot_chole
# Out:
# count    2001.000000
# mean      195.885557
# std        37.449064
# min       100.000000
# 25%       171.000000
# 50%       193.000000
# 75%       219.000000
# max       410.000000
# Name: tot_chole, dtype: float64

# %%
df.skew()
# Out:
# <ipython-input-17-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# age                  0.187686
# height              -0.057264
# weight               0.593609
# waistline            0.111046
# sight_left          10.123254
# sight_right          9.013094
# hear_left            5.672991
# hear_right           5.784483
# SBP                  0.351639
# DBP                  0.328475
# BLDS                 5.334696
# tot_chole            0.499298
# HDL_chole            0.802253
# LDL_chole            0.447551
# triglyceride         4.636381
# hemoglobin          -0.351401
# urine_protein        5.621270
# serum_creatinine     8.193721
# SGOT_AST             5.638615
# SGOT_ALT             3.531324
# gamma_GTP            8.167722
# ...

# %%
df.kurtosis()
# Out:
# <ipython-input-14-c7edf97eb14c>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurtosis()
# age                  -0.455555
# height               -0.525794
# weight                0.414435
# waistline            -0.084354
# sight_left          159.974594
# sight_right          95.839256
# hear_left            30.213023
# hear_right           31.491713
# SBP                   0.316969
# DBP                   0.806584
# BLDS                 48.910813
# tot_chole             0.919011
# HDL_chole             1.379475
# LDL_chole             0.829159
# triglyceride         45.800894
# hemoglobin            0.351897
# urine_protein        35.244629
# serum_creatinine    166.128081
# SGOT_AST             67.570652
# SGOT_ALT             19.965589
# ...

# %%
df.tot_chole.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hemoglobin.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.hemoglobin.plot.kde(ind=[1,2,3,4,5,6])
# Out:
# <Axes: ylabel='Density'>

# %%
df.urine_protein.plot()
# Out:
# <Axes: >

# %%
df.plot.box(vert=False)
# Out:
# <Axes: >

# %%
df.hemoglobin.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='tot_chole',y='waistline')# check
# Out:
# <Axes: xlabel='tot_chole', ylabel='waistline'>

# %%
df.plot.scatter(x='triglyceride',y='urine_protein')
# Out:
# <Axes: xlabel='triglyceride', ylabel='urine_protein'>

# %%
import seaborn as sns

# %%
df
# Out:
#          sex  age  height  weight  waistline  sight_left  sight_right  \
# 0       Male   35     170      75       90.0         1.0          1.0
# 1       Male   55     165      60       79.0         1.5          1.5
# 2     Female   60     155      50       78.0         1.0          0.9
# 3     Female   30     155      45       66.0         1.0          0.8
# 4       Male   45     160      70       79.0         0.5          0.5
# ...      ...  ...     ...     ...        ...         ...          ...
# 1996  Female   70     140      45       81.0         0.9          0.8
# 1997    Male   60     165      55       79.0         0.6          0.9
# 1998  Female   50     150      50       72.0         0.7          0.5
# 1999    Male   55     155      70       98.0         0.7          1.2
# 2000    Male   65     165      65       96.0         0.5          0.8
#
#       hear_left  hear_right  SBP  ...  LDL_chole  triglyceride  hemoglobin  \
# ...

# %%
corr = df.corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# <ipython-input-19-e01d510710de>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
